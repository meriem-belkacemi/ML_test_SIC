# %% [markdown]
# ## Quiz #0402

# %% [markdown]
# ### "OLS solution"

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Answer the following question by providing Python code:
# <br>
# study = an array that contains the hours of study. This is the explanatory variable. <br>
# score = an array that contains the test scores. This is the response variable.

# %%
study = np.array([ 3, 4.5, 6, 1.2, 2, 6.9, 6.7, 5.5]).reshape(-1,1)
score = np.array([ 88, 85, 90, 80, 81, 92, 95, 90]).reshape(-1,1)

# %% [markdown]
# 1). Define the 'linerRegression' class to match the output shown below:

# %%
class linearRegression:
    def __init__(self):
      return 
        
    def train(self, input_X, input_Y):
        n = input_X.shape[0]                                      # Number of observations.
        k = input_X.shape[1]                                      # Number of explanatory variables.
        
        # Regression Coefficients by OLS.
        mean_x = np.mean(input_X)
        mean_y = np.mean(input_Y)

        """ self.beta=[]
        numer = 0
        denom = 0
        for i in range(n):
          numer += (input_X[i] - mean_x) * (input_Y[i] - mean_y)
          denom += (input_X[i] - mean_x) ** 2
        m = numer / denom
        c = mean_y - (m * mean_x)
        self.beta.append(m)
        self.beta.append(c) """
        
        self.beta = np.matmul(np.matmul(np.linalg.inv(np.matmul(np.array(input_X).transpose(), np.array(input_X))), input_X.transpose()), input_Y)

        # Residuals.
        self.residuals = input_Y - np.dot(input_X,self.beta)
        
        # R^2.
       
        ss_t = 0
        ss_r = 0
        for i in range(n):
          y_pred = self.beta[0] + self.beta[1]* input_X[i]
          ss_t += (input_Y[i] - mean_y) ** 2
          ss_r += (input_Y[i] - y_pred) ** 2
        r2 = 1 - (ss_r/ss_t)
        self.r2=r2
      

        # Summary.
        

        return  
    


    def output(self):
      print("     Coefficient")
      print (f'Intercept    ', self.beta[0] )
      print (f'X1    ', self.beta[1])
      print("-----------------------")
      print(f'R^2 : ', self.r2)

# %% [markdown]
# **Sample run:**

# %%
LR = linearRegression()                    # Create a linear regression object.
LR.train(study, score)                     # Train.
LR.output()                                # Display the training result.
# Out:
#      Coefficient
# Intercept
# X1
# -----------------------
# R^2 :  [-35.02420255]
